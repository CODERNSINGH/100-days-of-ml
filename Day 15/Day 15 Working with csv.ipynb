# %% [markdown]
# # Method to handle CSV Files

# %%
import pandas as pd

# %% [markdown]
# ### Openining Local file

# %%
df = pd.read_csv("daily_and_month_call_report.csv")

# %%
df
# Out:
#      Year Month  Total Number of Calls  Total Number of Doctors Consultancy  \
# 0    2025   Feb                 155200                                98964
# 1    2025   Jan                 130982                                87815
# 2    2024   Dec                 133725                                86832
# 3    2024   Nov                 153698                                93710
# 4    2024   Oct                 214604                               108207
# ..    ...   ...                    ...                                  ...
# 102  2016   Aug                 142400                               112831
# 103  2016  July                 145061                               116686
# 104  2016  June                 186433                               152580
# 105  2016   May                 166635                               137326
# 106  2016   Apr                  51432                                43885
#
#      Number of Total Health Information  \
# ...

# %% [markdown]
# ### Opening a from URL
# * we don't have to learn this it will be avilable online
# * let's suppose link https://people.sc.fsu.edu/~jburkardt/data/csv/addresses.csv

# %%
import requests
from io import StringIO
url = "https://people.sc.fsu.edu/~jburkardt/data/csv/addresses.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"} # these are the Header's
req = requests.get(url, headers=headers)
data = StringIO(req. text)
df2 = pd.read_csv(data)

# %%
df2
# Out:
#                     John       Doe                 120 jefferson st.  \
# 0                   Jack  McGinnis                      220 hobo Av.
# 1          John "Da Man"    Repici                 120 Jefferson St.
# 2                Stephen     Tyler  7452 Terrace "At the Plaza" road
# 3                    NaN  Blankman                               NaN
# 4  Joan "the bone", Anne       Jet               9th, at Terrace plc
#
#      Riverside   NJ   08075
# 0        Phila   PA    9119
# 1    Riverside   NJ    8075
# 2     SomeTown   SD   91234
# 3     SomeTown   SD     298
# 4  Desert City   CO     123

# %%
df2.shape
# Out:
# (5, 6)

# %% [markdown]
# ## Sep Parameter
# * in read_csv sep is sep="," we can also change for differnt files for example tsv
#
# ### Let's Understand what if we have TSV file instad of csv

# %%
df = pd.read_csv("daily_and_month_call_report.csv", sep="\t")

# %%
df
# Out:
#     Year,Month,Total Number of Calls,Total Number of Doctors Consultancy,Number of Total Health Information,Number of Total Ambulance Information,Number of Total Complaints,Number of Calls To Know About The Service
# 0           2025,Feb,155200,98964,3777,5773,3706,42980
# 1           2025,Jan,130982,87815,3217,4179,3178,32593
# 2           2024,Dec,133725,86832,3634,3735,3035,36489
# 3           2024,Nov,153698,93710,3010,4421,4133,48424
# 4          2024,Oct,214604,108207,6307,5792,8885,80804
# ..                                                 ...
# 102         2016,Aug,142400,112831,12184,980,340,16065
# 103        2016,July,145061,116686,11831,922,404,15218
# 104        2016,June,186433,152580,14887,856,473,17637
# 105         2016,May,166635,137326,12118,925,439,15827
# 106              2016,Apr,51432,43885,3175,220,77,4075
#
# [107 rows x 1 columns]

# %% [markdown]
# ## Important Link
# link: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %% [markdown]
# # Using name parameter
# * passing Header's of table

# %%
df = pd.read_csv("daily_and_month_call_report.csv", names=['Year','Month',"Total Number of Calls Consultancy","Number of Total Complaints" ])

# %%
df
# Out:
#                                                                                                     Year  \
# Year Month Total Number of Calls Total Number of Doctors Consultancy  Number of Total Health Information
# 2025 Feb   155200                98964                                                              3777
#      Jan   130982                87815                                                              3217
# 2024 Dec   133725                86832                                                              3634
#      Nov   153698                93710                                                              3010
# ...                                                                                                  ...
# 2016 Aug   142400                112831                                                            12184
#      July  145061                116686                                                            11831
# ...

# %% [markdown]
# ## Index_col parameter
# * chaning a column into index

# %%
pd.read_csv("daily_and_month_call_report.csv",index_col="Month")
# Out:
#        Year  Total Number of Calls  Total Number of Doctors Consultancy  \
# Month
# Feb    2025                 155200                                98964
# Jan    2025                 130982                                87815
# Dec    2024                 133725                                86832
# Nov    2024                 153698                                93710
# Oct    2024                 214604                               108207
# ...     ...                    ...                                  ...
# Aug    2016                 142400                               112831
# July   2016                 145061                               116686
# June   2016                 186433                               152580
# May    2016                 166635                               137326
# Apr    2016                  51432                                43885
#
#        Number of Total Health Information  \
# Month
# Feb                                  3777
# ...

# %% [markdown]
# ## Header Parameter (important)
# * what if header is merged in data

# %%
pd.read_csv("daily_and_month_call_report.csv",header=1)
# Out:
#      2025   Feb  155200   98964   3777  5773  3706  42980
# 0    2025   Jan  130982   87815   3217  4179  3178  32593
# 1    2024   Dec  133725   86832   3634  3735  3035  36489
# 2    2024   Nov  153698   93710   3010  4421  4133  48424
# 3    2024   Oct  214604  108207   6307  5792  8885  80804
# 4    2024  Sept  157686   94893   3683  5685  4286  40889
# ..    ...   ...     ...     ...    ...   ...   ...    ...
# 101  2016   Aug  142400  112831  12184   980   340  16065
# 102  2016  July  145061  116686  11831   922   404  15218
# 103  2016  June  186433  152580  14887   856   473  17637
# 104  2016   May  166635  137326  12118   925   439  15827
# 105  2016   Apr   51432   43885   3175   220    77   4075
#
# [106 rows x 8 columns]

# %% [markdown]
# ## use_cols Parameter
# * somethimes we don't need extra columns so we can remove them on time of importing

# %%
pd.read_csv("daily_and_month_call_report.csv", usecols=['Month',"Year"])
# Out:
#      Year Month
# 0    2025   Feb
# 1    2025   Jan
# 2    2024   Dec
# 3    2024   Nov
# 4    2024   Oct
# ..    ...   ...
# 102  2016   Aug
# 103  2016  July
# 104  2016  June
# 105  2016   May
# 106  2016   Apr
#
# [107 rows x 2 columns]

# %% [markdown]
# ## Squeeze parameters

# %%
pd.read_csv("daily_and_month_call_report.csv",usecols=['Month'],squeeze=True )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 pd.read_csv("daily_and_month_call_report.csv",usecols=['Month'],squeeze=True )
#
# TypeError: read_csv() got an unexpected keyword argument 'squeeze'

# %% [markdown]
# ## Skipping/nrows Parameter
# * Skipping the rows which we don't Need
# * we can make a fuction and pass here that remove all the multiple rows of 5 something like that will be good

# %%
pd.read_csv("daily_and_month_call_report.csv", skiprows=[4,1])
# Out:
#      Year Month  Total Number of Calls  Total Number of Doctors Consultancy  \
# 0    2025   Jan                 130982                                87815
# 1    2024   Dec                 133725                                86832
# 2    2024   Oct                 214604                               108207
# 3    2024  Sept                 157686                                94893
# 4    2024   Aug                 168418                               100902
# ..    ...   ...                    ...                                  ...
# 100  2016   Aug                 142400                               112831
# 101  2016  July                 145061                               116686
# 102  2016  June                 186433                               152580
# 103  2016   May                 166635                               137326
# 104  2016   Apr                  51432                                43885
#
#      Number of Total Health Information  \
# ...

# %% [markdown]
# ## nrows

# %%
pd.read_csv("daily_and_month_call_report.csv", nrows=100)
# Out:
#     Year Month  Total Number of Calls  Total Number of Doctors Consultancy  \
# 0   2025   Feb                 155200                                98964
# 1   2025   Jan                 130982                                87815
# 2   2024   Dec                 133725                                86832
# 3   2024   Nov                 153698                                93710
# 4   2024   Oct                 214604                               108207
# ..   ...   ...                    ...                                  ...
# 95  2017   Mar                  71077                                47523
# 96  2017   Feb                  65846                                43645
# 97  2017   Jan                  75328                                51935
# 98  2016   Dec                 153487                               114676
# 99  2016   Nov                 130215                                94646
#
# ...

# %% [markdown]
# ## Encoding Parameters
# * Sometime on kaggle data don't have UTF-8  how to solve that
# * First way is to convet that file into UTF-8
# * Secondly we can do find encoding type of that file and use encoding="Type"

# %%
pd.read_csv("Mumbai Local Train Dataset.csv", encoding='latin-1')
# Out:
#             Station Station Code            Line  \
# 0        Churchgate          CCG         Western
# 1      Marine Lines          MEL         Western
# 2       Charni Road          CYR         Western
# 3        Grant Road          GTR         Western
# 4    Mumbai Central         MMCT         Western
# ..              ...          ...             ...
# 197           Neral          NRL  Neral-Matheran
# 198       Jumapatti          JTT  Neral-Matheran
# 199       Waterpipe          WTP  Neral-Matheran
# 200      Aman Lodge         AMNA  Neral-Matheran
# 201        Matheran          MAE  Neral-Matheran
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 0                                 0 KM                                0 min
# 1                                 1 KM                                3 min
# 2                                 1 KM                                2 min
# ...

# %% [markdown]
# ## Skip Badlines
# * sometimes some rows have extra values it will throw parseerror means having extra valus in rows than expected

# %%
pd.read_csv("Mumbai Local Train Dataset.csv", encoding='latin-1', error_bad_lines=False) # it will skip the row which containes error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 pd.read_csv("Mumbai Local Train Dataset.csv", encoding='latin-1', error_bad_lines=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'

# %% [markdown]
# ## Dtype parameter
# * Below we are converting int -> float

# %%
pd.read_csv("daily_and_month_call_report.csv",dtype={"Number of Total Health Information": float})
# Out:
#      Year Month  Total Number of Calls  Total Number of Doctors Consultancy  \
# 0    2025   Feb                 155200                                98964
# 1    2025   Jan                 130982                                87815
# 2    2024   Dec                 133725                                86832
# 3    2024   Nov                 153698                                93710
# 4    2024   Oct                 214604                               108207
# ..    ...   ...                    ...                                  ...
# 102  2016   Aug                 142400                               112831
# 103  2016  July                 145061                               116686
# 104  2016  June                 186433                               152580
# 105  2016   May                 166635                               137326
# 106  2016   Apr                  51432                                43885
#
#      Number of Total Health Information  \
# ...

# %% [markdown]
# ## Handling Dates
# * Basically sometimes in data dates are given in object(sting) we can change that using parse_dates=['dates']

# %%
pd.read_csv("countryLockdowndates.csv",parse_dates=['dates']) # chage to datetime64[ns]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 pd.read_csv("countryLockdowndates.csv")
#
# File /Applications/Anaconda/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
def rename(name):
    if name == 'Aug':
        return "Augest"
    else:
        return name

# %% [markdown]
# ## Convertors
# * Powerfull sometimes we have

# %%
pd.read_csv("daily_and_month_call_report.csv", converters={'Month':rename})
# Out:
#      Year Month  Total Number of Calls  Total Number of Doctors Consultancy  \
# 0    2025   Feb                 155200                                98964
# 1    2025   Jan                 130982                                87815
# 2    2024   Dec                 133725                                86832
# 3    2024   Nov                 153698                                93710
# 4    2024   Oct                 214604                               108207
# ..    ...   ...                    ...                                  ...
# 102  2016   Aug                 142400                               112831
# 103  2016  July                 145061                               116686
# 104  2016  June                 186433                               152580
# 105  2016   May                 166635                               137326
# 106  2016   Apr                  51432                                43885
#
#      Number of Total Health Information  \
# ...

# %% [markdown]
# ## na_values parameter

# %%
pd.read_csv("countryLockdowndates.csv",na_values=['Dec'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.read_csv("countryLockdowndates.csv",na_values=['Dec'])
#
# File /Applications/Anaconda/anaconda3/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
