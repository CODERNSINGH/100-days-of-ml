# %% [markdown]
# ## Fatching Data From API
# * my api keys : 52e6ee5bcff00b1538085d0c77a863df
# * https://api.themoviedb.org/3/movie/top_rated?api_key=52e6ee5bcff00b1538085d0c77a863df&language=en-US&page=1

# %%
import pandas as pd
import requests

# %%
df = pd.read_json('https://api.themoviedb.org/3/movie/top_rated?api_key=52e6ee5bcff00b1538085d0c77a863df&language=en-US&page=1')
df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/zfbjgQE1uS...          503
# 1      1  {'adult': False, 'backdrop_path': '/tmU7GeKVyb...          503
# 2      1  {'adult': False, 'backdrop_path': '/kGzFbGhp99...          503
# 3      1  {'adult': False, 'backdrop_path': '/zb6fM1CX41...          503
# 4      1  {'adult': False, 'backdrop_path': '/bxgTSUenZD...          503
# 5      1  {'adult': False, 'backdrop_path': '/6oaL4DP75y...          503
# 6      1  {'adult': False, 'backdrop_path': '/90ez6ArvpO...          503
# 7      1  {'adult': False, 'backdrop_path': '/oOv2oUXcAa...          503
# 8      1  {'adult': False, 'backdrop_path': '/vxJ08Svwom...          503
# 9      1  {'adult': False, 'backdrop_path': '/hiKmpZMGZs...          503
# 10     1  {'adult': False, 'backdrop_path': '/suaEOtk1N1...          503
# 11     1  {'adult': False, 'backdrop_path': '/deUWVEgNh2...          503
# ...

# %%
df['results'][0]
# Out:
# {'adult': False,
#  'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#  'genre_ids': [18, 80],
#  'id': 278,
#  'original_language': 'en',
#  'original_title': 'The Shawshank Redemption',
#  'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#  'popularity': 6.438,
#  'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#  'release_date': '1994-09-23',
#  'title': 'The Shawshank Redemption',
#  'video': False,
#  'vote_average': 8.7,
#  'vote_count': 27914}

# %% [markdown]
# ## what's happning in background
# * requests.get(url) is used in the backend to send an HTTP GET request to a specified URL and retrieve data from a server. It fetches responses like JSON, HTML, or text, which can be processed further. Common use cases include API calls, web scraping, and microservice communication.

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=52e6ee5bcff00b1538085d0c77a863df&language=en-US&page=1')

# %%
tem = response.json()

# %%
df = pd.DataFrame(tem['results'])

# %%
df
# Out:
#     adult                     backdrop_path         genre_ids       id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
# 4   False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg              [18]      389
# 5   False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg   [16, 10751, 14]      129
# 6   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]    19404
# 7   False  /oOv2oUXcAaNXakRqUPxYq5lJURz.jpg  [18, 28, 80, 53]      155
# 8   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]      497
# 9   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]   496243
# 10  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]      680
# 11  False  /deUWVEgNh2IGjShyymZhaYP40ye.jpg      [28, 12, 53]  1356039
# ...

# %%
df.head()
# Out:
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]  278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         [18, 80]  238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
# 4  False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg             [18]  389
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
# 4                en              12 Angry Men
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...       6.438
# 1  Spanning the years 1945 to 1955, a chronicle o...       5.614
# 2  In the continuing saga of the Corleone crime f...       5.622
# ...

# %%
df[['original_title','poster_path','popularity','vote_count','original_language','adult']]
# Out:
#                                    original_title  \
# 0                        The Shawshank Redemption
# 1                                   The Godfather
# 2                           The Godfather Part II
# 3                                Schindler's List
# 4                                    12 Angry Men
# 5                                        千と千尋の神隠し
# 6                    दिलवाले दुल्हनिया ले जायेंगे
# 7                                 The Dark Knight
# 8                                  The Green Mile
# 9                                             기생충
# 10                                   Pulp Fiction
# 11                                   Contraataque
# 12                                          君の名は。
# 13  The Lord of the Rings: The Return of the King
# 14                                   Forrest Gump
# 15                Il buono, il brutto, il cattivo
# 16                                           七人の侍
# 17                                     GoodFellas
# ...

# %% [markdown]
# # What if i have more than one page how to Fetch that data

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Travling each Page

# %%
for i in range(1,101):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=52e6ee5bcff00b1538085d0c77a863df&language=en-US&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/vj/75w9dcg10yjc8y2pkhsc_9cr0000gn/T/ipykernel_43274/1065566724.py in ?()
#       1 for i in range(1,101):
#       2     response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=52e6ee5bcff00b1538085d0c77a863df&language=en-US&page={i}')
#       3     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# ----> 4     df = df.append(temp_df,ignore_index=True)
#       5
#
# /Applications/Anaconda/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# ...

# %%
for i in range(1,101):
    url = f"https://api.themoviedb.org/3/movie/top_rated?api_key=52e6ee5bcff00b1538085d0c77a863df&language=en-US&page={i}"
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=52e6ee5bcff00b1538085d0c77a863df&language=en-US&page=1').json()['results'][['original_title','poster_path','popularity','vote_count','original_language','adult']]

    allMovies.extend(response)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 3
#       1 for i in range(1,101):
#       2     url = f"https://api.themoviedb.org/3/movie/top_rated?api_key=52e6ee5bcff00b1538085d0c77a863df&language=en-US&page={i}"
# ----> 3     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=52e6ee5bcff00b1538085d0c77a863df&language=en-US&page=1').json()['results'][['original_title','poster_path','popularity','vote_count','original_language','adult']]
#       5     allMovies.extend(response)
#
# TypeError: list indices must be integers or slices, not list

# %%
df = pd.DataFrame(allMovies)

# %%
df
# Out:
#                                                    0   \
# 0   {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
# 1   {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
# 2   {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
# 3   {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
# 4   {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
# ..                                                ...
# 95  {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
# 96  {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
# 97  {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
# 98  {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
# 99  {'adult': False, 'backdrop_path': '/zfbjgQE1uS...
#
#                                                    1   \
# 0   {'adult': False, 'backdrop_path': '/tmU7GeKVyb...
# 1   {'adult': False, 'backdrop_path': '/tmU7GeKVyb...
# 2   {'adult': False, 'backdrop_path': '/tmU7GeKVyb...
# 3   {'adult': False, 'backdrop_path': '/tmU7GeKVyb...
# ...
